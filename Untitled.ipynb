# %% [markdown]
# ## Import package

# %%
import cv2
import numpy as np
import cv2
from mss import mss
from PIL import Image
import matplotlib.pyplot as plt

bounding_box = {'top': 100, 'left': 0, 'width': 400, 'height': 300}

sct = mss()

# %% [markdown]
# ## Detect

# %%
# capture frames from a video
cap = cv2.imread('carpit.jpg')

# Trained XML classifiers describes some features of some object we want to detect
car_cascade = cv2.CascadeClassifier('cars.xml')

# loop runs if capturing has been initialized.

#     ret, frames = cap.read()
gray = cv2.cvtColor(cap, cv2.COLOR_BGR2GRAY)
    
cars = car_cascade.detectMultiScale(gray, 1.1, 1)
for (x,y,w,h) in cars:
    cv2.rectangle(cap,(x,y),(x+w,y+h),(0,0,255),2)   

# Display frames in a window
plt.imshow(cv2.cvtColor(cap, cv2.COLOR_BGR2RGB))

# %%
# OpenCV Python program to detect cars in video frame
# import libraries of python OpenCV
import cv2

# capture frames from a video
cap = cv2.VideoCapture('car3.mkv')

# Trained XML classifiers describes some features of some object we want to detect
car_cascade = cv2.CascadeClassifier('cars.xml')

# loop runs if capturing has been initialized.
while True:
    ret, frames = cap.read()
    gray = cv2.cvtColor(frames, cv2.COLOR_BGR2GRAY)
    
    cars = car_cascade.detectMultiScale(gray, 1.1, 1)
    for (x,y,w,h) in cars:
        cv2.rectangle(frames,(x,y),(x+w,y+h),(0,0,255),2)

# Display frames in a window
    cv2.imshow('video2', frames)
 
 # Wait for Esc key to stop
    if cv2.waitKey(33) == 27:
            break

# De-allocate any associated memory usage
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-90902e50393f> in <module>
#      14     gray = cv2.cvtColor(frames, cv2.COLOR_BGR2GRAY)
#      15
# ---> 16     cars = car_cascade.detectMultiScale(gray, 1.1, 1)
#      17     for (x,y,w,h) in cars:
#      18         cv2.rectangle(frames,(x,y),(x+w,y+h),(0,0,255),2)
#
# KeyboardInterrupt:
